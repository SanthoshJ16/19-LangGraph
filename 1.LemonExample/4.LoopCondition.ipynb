# %%
from IPython.display import display, HTML
inner_html = """
<div style="font-family:Segoe UI,Arial,sans-serif;line-height:1.6;">

    <h2 style="color:#0078d4;">
        LangGraph Looping Workflow Example - Smart Lemonade Preparation
    </h2>

    <p>
        This example demonstrates one of the most powerful features of
        <b>LangGraph</b>: <b>Loops</b>. Unlike a traditional workflow that
        progresses linearly, this graph repeatedly executes steps until a
        desired condition is met.
    </p>

    <h3>🎯 Business Scenario</h3>

    <p>
        The lemonade preparation process should continue adding sugar until
        the drink becomes sweet enough. Instead of deciding once and moving
        forward, the workflow loops back, rechecks sweetness, and continues
        until the expected taste is achieved.
    </p>

    <h3>📦 State Definition</h3>

    <p>
        <b>LemonLoopState</b> acts as the shared memory between all nodes.
    </p>

    <ul>
        <li><b>lemons</b> → Number of lemons used.</li>
        <li><b>sugar</b> → Current sugar quantity.</li>
        <li><b>water</b> → Water quantity.</li>
        <li><b>juice</b> → Lemon juice generated.</li>
        <li><b>mix</b> → Current lemonade mixture.</li>
        <li><b>sweet</b> → Indicates whether lemonade is sweet enough.</li>
        <li><b>attempts</b> → Number of sugar adjustments made.</li>
        <li><b>final</b> → Final drink output.</li>
    </ul>

    <h3>🔧 Processing Nodes</h3>

    <ul>
        <li>
            <b>squeeze_lemons()</b><br>
            Extracts juice from the lemons.
        </li>

        <li>
            <b>add_water()</b><br>
            Adds water to the juice.
        </li>

        <li>
            <b>add_sugar()</b><br>
            Adds one spoon of sugar and increments the attempt counter.
        </li>

        <li>
            <b>taste_and_check()</b><br>
            Evaluates whether the lemonade is sweet enough.
        </li>

        <li>
            <b>serve()</b><br>
            Serves the lemonade once the desired sweetness level is reached.
        </li>
    </ul>

    <h3>🧠 Loop Decision Logic</h3>

    <p>
        The graph uses a conditional edge to determine whether to continue
        looping or finish the workflow.
    </p>

    <pre style="background:#f4f4f4;padding:10px;">
If sweet = True
    → serve

Else
    → add_sugar
    → taste_and_check
    → repeat
    </pre>

    <h3>🔄 Workflow Diagram</h3>

    <div style="background:#f8f9fa;padding:15px;border-radius:6px;
                font-family:Consolas,monospace;">

squeeze_lemons<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
add_water<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
taste_and_check<br>
&nbsp;&nbsp;&nbsp;&nbsp;/&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\\<br>
Sweet?&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Not Sweet<br>
&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
serve&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;add_sugar<br>
&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
END&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;taste_and_check<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↺ (Loop)

    </div>

    <h3>🚀 Execution Flow</h3>

    <ol>
        <li>Squeeze lemons.</li>
        <li>Add water.</li>
        <li>Taste the mixture.</li>
        <li>If not sweet, add sugar.</li>
        <li>Check sweetness again.</li>
        <li>Repeat until sweet enough.</li>
        <li>Serve lemonade.</li>
    </ol>

    <h3>🧪 Example Execution</h3>

    <div style="background:#e8f4fd;padding:12px;
                border-left:4px solid #0078d4;border-radius:4px;">

        <b>Initial Input</b><br>
        Lemons = 4<br>
        Sugar = 0<br>
        Water = 1 Glass
        <br><br>

        <b>Iteration 1</b><br>
        Sugar = 0 → Not Sweet
        <br><br>

        <b>Iteration 2</b><br>
        Sugar = 1 → Still Not Sweet
        <br><br>

        <b>Iteration 3</b><br>
        Sugar = 2 → Sweet
        <br><br>

        <b>Final Path</b><br>
        squeeze_lemons → add_water → taste_and_check
        → add_sugar → taste_and_check
        → add_sugar → taste_and_check
        → serve
    </div>

    <br>

    <h3>📊 Result DataFrame</h3>

    <p>
        After workflow completion, the final state is converted into a
        Pandas DataFrame for inspection and reporting.
    </p>

    <pre style="background:#f4f4f4;padding:10px;">
result_df = pd.DataFrame([result])
result_df
    </pre>

    <h3>📋 Sample Final State</h3>

    <div style="background:#fff4ce;padding:12px;
                border-left:4px solid #ffb900;border-radius:4px;">

        <b>lemons:</b> 4<br>
        <b>sugar:</b> 2<br>
        <b>water:</b> 1 glass<br>
        <b>sweet:</b> True<br>
        <b>attempts:</b> 2<br>
        <b>final:</b> Juice from 4 lemons + 1 glass water + 1 spoons sugar + 2 spoons sugar → Served!

    </div>

    <br>

    <h3>🎯 LangGraph Concepts Demonstrated</h3>

    <div style="background:#f3f2f1;padding:12px;border-radius:6px;">

        <b>State</b> → Shared workflow memory<br><br>

        <b>Node</b> → Individual processing step<br><br>

        <b>Edge</b> → Connection between nodes<br><br>

        <b>Conditional Edge</b> → Decision-making logic<br><br>

        <b>Loop</b> → Repeat execution until condition is met<br><br>

        <b>State Update</b> → Nodes continuously update shared state<br><br>

        <b>Finish Point</b> → Workflow terminates when sweet=True

    </div>

    <br>

    <div style="background:#dff6dd;padding:12px;
                border-left:4px solid #107c10;border-radius:4px;">
        <strong>
            Key Learning: Loops are a major advantage of LangGraph over traditional
            LangChain workflows. They enable self-correcting processes where an AI
            system can repeatedly evaluate results, retry actions, and continue until
            a desired outcome is achieved. This pattern is widely used in Incident
            Resolution, Root Cause Analysis, Agentic AI, Autonomous Workflows,
            Testing Cycles, and Human Approval Processes.
        </strong>
    </div>

</div>
"""
display(HTML(inner_html))
# Out:
# <div style="font-family:Segoe UI,Arial,sans-serif;line-height:1.6;">
#
#     <h2 style="color:#0078d4;">
#         LangGraph Looping Workflow Example - Smart Lemonade Preparation
#     </h2>
#
#     <p>
#         This example demonstrates one of the most powerful features of
#         <b>LangGraph</b>: <b>Loops</b>. Unlike a traditional workflow that
#         progresses linearly, this graph repeatedly executes steps until a
#         desired condition is met.
#     </p>
#
#     <h3>🎯 Business Scenario</h3>
#
#     <p>
#         The lemonade preparation process should continue adding sugar until
#         the drink becomes sweet enough. Instead of deciding once and moving
#         forward, the workflow loops back, rechecks sweetness, and continues
#         until the expected taste is achieved.
#     </p>
#
#     <h3>📦 State Definition</h3>
#
#     <p>
#         <b>LemonLoopState</b> acts as the shared memory between all nodes.
#     </p>
#
#     <ul>
# ...

# %%
# Re-execute after environment reset
from langgraph.graph import StateGraph
from typing import TypedDict, Dict, Any

# 1. Define state
class LemonLoopState(TypedDict):
    lemons: int
    sugar: int
    water: str
    juice: str
    mix: str
    final: str
    sweet: bool
    attempts: int

# 2. Define nodes
def squeeze_lemons(state: Dict[str, Any]) -> Dict[str, Any]:
    state["juice"] = f"Juice from {state['lemons']} lemons"
    return state

def add_water(state: Dict[str, Any]) -> Dict[str, Any]:
    state["mix"] = f"{state['juice']} + {state['water']} water"
    return state

def add_sugar(state: Dict[str, Any]) -> Dict[str, Any]:
    state["sugar"] += 1
    state["mix"] = f"{state['mix']} + {state['sugar']} spoons sugar"
    state["attempts"] += 1
    return state

def taste_and_check(state: Dict[str, Any]) -> Dict[str, Any]:
    # Simulate taste: sweet if sugar >= 2
    state["sweet"] = state["sugar"] >= 2
    return state

def serve(state: Dict[str, Any]) -> Dict[str, Any]:
    state["final"] = f"{state['mix']} → Served!"
    return state

# 3. Build graph
builder = StateGraph(LemonLoopState)
builder.add_node("squeeze_lemons", squeeze_lemons)
builder.add_node("add_water", add_water)
builder.add_node("add_sugar", add_sugar)
builder.add_node("taste_and_check", taste_and_check)
builder.add_node("serve", serve)

builder.set_entry_point("squeeze_lemons")
builder.add_edge("squeeze_lemons", "add_water")
builder.add_edge("add_water", "taste_and_check")

# Loop condition
def check_sweetness(state: Dict[str, Any]) -> str:
    return "serve" if state["sweet"] else "add_sugar"

builder.add_conditional_edges("taste_and_check", check_sweetness, {
    "serve": "serve",
    "add_sugar": "add_sugar"
})

builder.add_edge("add_sugar", "taste_and_check")
#builder.add_edge("serve","taste_and_check")
builder.set_finish_point("serve")
from IPython.display import Image, display
graph = builder.compile()
# Visualize
from IPython.display import Image, Markdown, display

graph = builder.compile()

# Visualize
try:
    png_data = graph.get_graph().draw_mermaid_png()
    display(Image(png_data))

except Exception as e:
    print(f"Graph Visualization Failed: {e}")

    mermaid_code = graph.get_graph().draw_mermaid()

    display(
        Markdown(
            f"```mermaid\n{mermaid_code}\n```"
        )
    )

# Initial state
state = {
    "lemons": 4,
    "sugar": 0,
    "water": "1 glass",
    "juice": "",
    "mix": "",
    "final": "",
    "sweet": False,
    "attempts": 0
}

import pandas as pd
result_df = pd.DataFrame([result])
result_df
# Out:
# Graph Visualization Failed: Failed to reach https://mermaid.ink API while trying to render your graph after 1 retries. To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	squeeze_lemons(squeeze_lemons)
# 	add_water(add_water)
# 	add_sugar(add_sugar)
# 	taste_and_check(taste_and_check)
# 	serve(serve)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> squeeze_lemons;
# 	add_sugar --> taste_and_check;
# 	add_water --> taste_and_check;
# 	squeeze_lemons --> add_water;
# 	taste_and_check -.-> add_sugar;
# 	taste_and_check -.-> serve;
# 	serve --> __end__;
# ...
