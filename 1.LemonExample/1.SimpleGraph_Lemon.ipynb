# %%
from IPython.display import display, HTML
innerHtml = """
<div style="font-family:Segoe UI,Arial,sans-serif; line-height:1.6;">

    <h2>LangChain vs LangGraph</h2>

    <table border="1" cellpadding="8" cellspacing="0" style="border-collapse:collapse; width:100%;">
        <tr style="background-color:#f2f2f2;">
            <th>Feature</th>
            <th>LangChain</th>
            <th>LangGraph</th>
        </tr>
        <tr>
            <td>Linear Workflow</td>
            <td>✅</td>
            <td>✅</td>
        </tr>
        <tr>
            <td>Conditional Routing</td>
            <td>❌</td>
            <td>✅</td>
        </tr>
        <tr>
            <td>Loops & Retry Logic</td>
            <td>❌</td>
            <td>✅</td>
        </tr>
        <tr>
            <td>Multi-Agent Systems</td>
            <td>Limited</td>
            <td>✅</td>
        </tr>
        <tr>
            <td>Stateful Workflow</td>
            <td>Limited</td>
            <td>✅</td>
        </tr>
        <tr>
            <td>Human Approval / Human-in-the-Loop</td>
            <td>Limited</td>
            <td>✅</td>
        </tr>
        <tr>
            <td>Complex Enterprise Applications</td>
            <td>Moderate</td>
            <td>✅</td>
        </tr>
    </table>

    <br/>

    <h2>LangGraph Use Case</h2>

    <div style="font-family:Consolas,monospace; background:#f8f9fa; padding:15px; border-radius:5px;">
Incident Raised<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
Incident Classifier<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
Is Known Issue?<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;/&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\<br/>
&nbsp;&nbsp;&nbsp;Yes&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;No<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
KB Search&nbsp;&nbsp;&nbsp;&nbsp;SME Agent<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
Resolution Generator<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
Human Approval<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
Ticket Update
    </div>

    <br/>

    <p>
        This is a perfect <b>LangGraph</b> use case because multiple agents collaborate,
        make decisions dynamically, leverage KB articles, involve SMEs when needed,
        and include human approval before updating the ticket.
    </p>

    <h2>One-Line Summary</h2>

    <div style="background:#e8f4fd; padding:12px; border-left:5px solid #0078d4; border-radius:4px;">
        <strong>
            LangChain is a single intelligent worker following a fixed process,
            whereas LangGraph is a team of intelligent workers collaborating,
            making decisions, and dynamically choosing the next action to solve
            complex problems.
        </strong>
    </div>

</div>
<div style="font-family:Segoe UI, Arial, sans-serif; line-height:1.6; padding:15px; border:1px solid #dcdcdc; border-radius:8px; background:#f8f9fa;">

    <h2 style="color:#0078d4;">Why LangGraph?</h2>

    <p>
        Normal <b>LangChain</b> works well for:
    </p>

    <ul>
        <li>Chatbots</li>
        <li>RAG Applications</li>
        <li>Prompt Chaining</li>
    </ul>

    <p>
        But when you need:
    </p>

    <ul>
        <li>Multiple AI Agents</li>
        <li>Decision Making</li>
        <li>Loops and Retry Logic</li>
        <li>Human Approvals (Human-in-the-Loop)</li>
        <li>Complex Workflows</li>
    </ul>

    <div style="background:#e8f4fd; padding:12px; border-left:4px solid #0078d4; border-radius:4px; margin-top:10px;">
        <strong>
            LangGraph becomes useful because it enables dynamic workflows where multiple AI agents can collaborate, make decisions, maintain state, and route tasks intelligently based on the context.
        </strong>
    </div>

</div>
<div style="font-family:Segoe UI, Arial, sans-serif; line-height:1.6; padding:15px; border:1px solid #dcdcdc; border-radius:8px; background:#f8f9fa;">

    <h2 style="color:#0078d4;">Where LangGraph is Used</h2>

    <h3>🎧 Customer Support</h3>
    <ul>
        <li>Ticket Classification</li>
        <li>Auto Resolution</li>
        <li>Escalation Handling</li>
    </ul>

    <h3>🛠️ IT Operations (AMS)</h3>
    <ul>
        <li>Incident Analysis</li>
        <li>Root Cause Identification</li>
        <li>Knowledge Base (KB) Article Search</li>
        <li>Resolution Recommendations</li>
    </ul>

    <h3>💻 Software Development</h3>
    <ul>
        <li>Requirement Analysis</li>
        <li>Code Generation</li>
        <li>Testing & Validation</li>
        <li>Code Review</li>
    </ul>

    <h3>🤖 Enterprise Assistants</h3>
    <ul>
        <li>Retrieval-Augmented Generation (RAG)</li>
        <li>Multi-Agent Systems</li>
        <li>Human Approval Workflows</li>
    </ul>

    <div style="margin-top:15px; padding:12px; background:#e8f4fd; border-left:4px solid #0078d4; border-radius:4px;">
        <strong>Why it matters:</strong>
        LangGraph is ideal for enterprise scenarios where multiple AI agents must
        collaborate, make decisions, maintain context, interact with humans,
        and execute complex workflows dynamically.
    </div>

</div>
"""
display(HTML(innerHtml))
# Out:
# <div style="font-family:Segoe UI,Arial,sans-serif; line-height:1.6;">
#
#     <h2>LangChain vs LangGraph</h2>
#
#     <table border="1" cellpadding="8" cellspacing="0" style="border-collapse:collapse; width:100%;">
#         <tr style="background-color:#f2f2f2;">
#             <th>Feature</th>
#             <th>LangChain</th>
#             <th>LangGraph</th>
#         </tr>
#         <tr>
#             <td>Linear Workflow</td>
#             <td>✅</td>
#             <td>✅</td>
#         </tr>
#         <tr>
#             <td>Conditional Routing</td>
#             <td>❌</td>
#             <td>✅</td>
#         </tr>
#         <tr>
#             <td>Loops & Retry Logic</td>
#             <td>❌</td>
#             <td>✅</td>
#         </tr>
#         <tr>
#             <td>Multi-Agent Systems</td>
#             <td>Limited</td>
#             <td>✅</td>
#         </tr>
#         <tr>
#             <td>Stateful Workflow</td>
#             <td>Limited</td>
#             <td>✅</td>
# ...

# %%
langgraph_comments_html = """
<div style='font-family:Segoe UI,Arial,sans-serif;line-height:1.6;'>

    <h2 style='color:#0078d4;'>LangGraph Lemonade Example - Code Explanation</h2>

    <h3>1. Import Required Libraries</h3>
    <ul>
        <li><b>StateGraph</b> is used to create the workflow graph.</li>
        <li><b>Dict</b> and <b>Any</b> provide type hints for the state object.</li>
        <li><b>Image</b> and <b>display</b> are used to visualize the graph.</li>
    </ul>

    <h3>2. Define Graph Nodes</h3>
    <p>
        Each function represents a <b>node</b> in the LangGraph workflow.
        A node performs a specific task and updates the shared state.
    </p>

    <ul>
        <li>
            <b>squeeze_lemons()</b><br>
            Takes the number of lemons from the state and creates lemon juice.
        </li>
        <li>
            <b>add_sugar_and_water()</b><br>
            Combines lemon juice, sugar, and water to prepare the mixture.
        </li>
        <li>
            <b>stir_and_serve()</b><br>
            Produces the final lemonade and marks it as ready to serve.
        </li>
    </ul>

    <h3>3. Define State Schema</h3>
    <p>
        <b>LemonState</b> is a TypedDict that defines the structure of the
        data shared between all nodes.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
lemons → Number of lemons
sugar  → Sugar quantity
water  → Water quantity
juice  → Juice generated
mix    → Prepared mixture
final  → Final lemonade output
    </pre>

    <h3>4. Create the Graph</h3>
    <p>
        A StateGraph instance is created using LemonState. This graph
        controls how nodes interact with each other.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
builder = StateGraph(LemonState)
    </pre>

    <h3>5. Add Nodes</h3>
    <p>
        Each processing step is registered as a node.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
builder.add_node("squeeze_lemons", squeeze_lemons)
builder.add_node("add_sugar_and_water", add_sugar_and_water)
builder.add_node("stir_and_serve", stir_and_serve)
    </pre>

    <h3>6. Define Workflow Path</h3>
    <p>
        The graph is configured to execute the nodes in sequence.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
squeeze_lemons
        ↓
add_sugar_and_water
        ↓
stir_and_serve
    </pre>

    <ul>
        <li><b>set_entry_point()</b> defines the starting node.</li>
        <li><b>add_edge()</b> defines the transition between nodes.</li>
        <li><b>set_finish_point()</b> defines the final node.</li>
    </ul>

    <h3>7. Compile the Graph</h3>
    <p>
        Compilation converts the workflow definition into an executable graph.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
graph = builder.compile()
    </pre>

    <h3>8. Visualize the Workflow</h3>
    <p>
        Mermaid visualization generates a graphical view of the workflow,
        making it easy to understand node execution flow.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
display(Image(graph.get_graph().draw_mermaid_png()))
    </pre>

    <h3>9. Initialize Input State</h3>
    <p>
        The initial state contains the ingredients required to prepare lemonade.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
lemons = 4
sugar = 2 spoons
water = 1 glass
    </pre>

    <h3>10. Execute the Graph</h3>
    <p>
        The invoke() method starts the workflow from the entry node and
        automatically executes all connected nodes until the finish node is reached.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
result = graph.invoke(initial_state)
    </pre>

    <h3>11. Retrieve Final Output</h3>
    <p>
        The final state contains all intermediate and final results generated
        by the workflow.
    </p>

    <pre style='background:#f4f4f4;padding:10px;'>
print(result["final"])
    </pre>

    <h3>Workflow Execution Summary</h3>

    <div style='background:#e8f4fd;padding:12px;border-left:4px solid #0078d4;border-radius:4px;'>
        <b>Input State</b><br>
        Lemons = 4, Sugar = 2, Water = 1 Glass
        <br><br>
        <b>Step 1:</b> Squeeze Lemons → Juice Created<br>
        <b>Step 2:</b> Add Sugar & Water → Mixture Prepared<br>
        <b>Step 3:</b> Stir & Serve → Final Lemonade Ready
        <br><br>
        <b>Final Output:</b><br>
        Juice from 4 lemons + 2 spoons sugar + 1 glass water → Stirred and ready to serve!
    </div>

    <br>

    <div style='background:#fff4ce;padding:12px;border-left:4px solid #ffb900;border-radius:4px;'>
        <b>LangGraph Concept Demonstrated:</b><br>
        Node → Function<br>
        Edge → Connection between Functions<br>
        State → Shared Data Object<br>
        Graph → Complete Workflow<br>
        Invoke → Execute Workflow
    </div>

</div>
"""
display(HTML(langgraph_comments_html))
# Out:
# <div style='font-family:Segoe UI,Arial,sans-serif;line-height:1.6;'>
#
#     <h2 style='color:#0078d4;'>LangGraph Lemonade Example - Code Explanation</h2>
#
#     <h3>1. Import Required Libraries</h3>
#     <ul>
#         <li><b>StateGraph</b> is used to create the workflow graph.</li>
#         <li><b>Dict</b> and <b>Any</b> provide type hints for the state object.</li>
#         <li><b>Image</b> and <b>display</b> are used to visualize the graph.</li>
#     </ul>
#
#     <h3>2. Define Graph Nodes</h3>
#     <p>
#         Each function represents a <b>node</b> in the LangGraph workflow.
#         A node performs a specific task and updates the shared state.
#     </p>
#
#     <ul>
#         <li>
#             <b>squeeze_lemons()</b><br>
#             Takes the number of lemons from the state and creates lemon juice.
#         </li>
#         <li>
#             <b>add_sugar_and_water()</b><br>
#             Combines lemon juice, sugar, and water to prepare the mixture.
# ...

# %%
from langgraph.graph import StateGraph
from typing import Dict, Any
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod
import nest_asyncio
nest_asyncio.apply()

# Define nodes
def squeeze_lemons(state: Dict[str, Any]) -> Dict[str, Any]:
    state["juice"] = f"Juice from {state.get('lemons', 0)} lemons"
    return state

def add_sugar_and_water(state: Dict[str, Any]) -> Dict[str, Any]:
    state["mix"] = f"{state['juice']} + {state.get('sugar', 0)} spoons sugar + {state.get('water', '')} water"
    return state

def stir_and_serve(state: Dict[str, Any]) -> Dict[str, Any]:
    state["final"] = f"{state['mix']} → Stirred and ready to serve!"
    return state

from typing import TypedDict

class LemonState(TypedDict):
    lemons: int
    sugar: int
    water: str
    juice: str
    mix: str
    final: str


# Build graph
builder = StateGraph(LemonState)
builder.add_node("squeeze_lemons", squeeze_lemons)
builder.add_node("add_sugar_and_water", add_sugar_and_water)
builder.add_node("stir_and_serve", stir_and_serve)

builder.set_entry_point("squeeze_lemons")
builder.add_edge("squeeze_lemons", "add_sugar_and_water")
builder.add_edge("add_sugar_and_water", "stir_and_serve")
builder.set_finish_point("stir_and_serve")

graph = builder.compile()

# ✅ Visualize as Mermaid PNG
from IPython.display import Markdown, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(
                draw_method=MermaidDrawMethod.PYPPETEER
            )
        )
    )

except Exception as e:
    print(f"PNG Visualization Failed: {e}")

    mermaid_code = graph.get_graph().draw_mermaid()

    display(
        Markdown(
            f"```mermaid\n{mermaid_code}\n```"
        )
    )
# Out:
# [INFO] Starting Chromium download.
# PNG Visualization Failed: HTTPSConnectionPool(host='storage.googleapis.com', port=443): Max retries exceeded with url: /chromium-browser-snapshots/Win_x64/1181205/chrome-win.zip (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)')))
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	squeeze_lemons(squeeze_lemons)
# 	add_sugar_and_water(add_sugar_and_water)
# 	stir_and_serve(stir_and_serve)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> squeeze_lemons;
# 	add_sugar_and_water --> stir_and_serve;
# 	squeeze_lemons --> add_sugar_and_water;
# 	stir_and_serve --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```

# %%
# Initial input state
initial_state: LemonState = {
    "lemons": 4,
    "sugar": 2,
    "water": "1 glass",
    "juice": "",
    "mix": "",
    "final": ""
}

# Run the LangGraph
result = graph.invoke(initial_state)

# Print final result
print("🧃 Final Output:", result["final"])
# Out:
# 🧃 Final Output: Juice from 4 lemons + 2 spoons sugar + 1 glass water → Stirred and ready to serve!
