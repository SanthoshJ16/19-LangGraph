# %%
from IPython.display import display, HTML
langgraph_double_condition_html = """
<div style="font-family:Segoe UI,Arial,sans-serif;line-height:1.6;">

    <h2 style="color:#0078d4;">
        LangGraph Multi-Level Conditional Routing Example
    </h2>

    <p>
        This example demonstrates how <b>LangGraph</b> can perform
        <b>multiple decision-making steps</b> within the same workflow.
        The graph first decides whether sugar should be added and then
        decides how the lemonade should be served.
    </p>

    <h3>🎯 Business Scenario</h3>

    <p>
        We are preparing lemonade dynamically based on user preferences:
    </p>

    <ul>
        <li>If sugar is available, add sugar and water.</li>
        <li>If sugar is unavailable, add only water.</li>
        <li>If the customer prefers a cold drink, chill and serve.</li>
        <li>Otherwise, stir and serve normally.</li>
    </ul>

    <h3>📦 State Object</h3>

    <p>
        <b>LemonState</b> acts as a shared memory that is accessible by all nodes.
    </p>

    <ul>
        <li><b>lemons</b> → Number of lemons</li>
        <li><b>sugar</b> → Sugar quantity</li>
        <li><b>water</b> → Quantity of water</li>
        <li><b>prefer_cold</b> → Customer serving preference</li>
        <li><b>juice</b> → Juice generated</li>
        <li><b>mix</b> → Lemonade mixture</li>
        <li><b>final</b> → Final output</li>
    </ul>

    <h3>🔧 Processing Nodes</h3>

    <ul>
        <li><b>squeeze_lemons()</b> → Extract lemon juice.</li>
        <li><b>add_sugar_and_water()</b> → Add sugar and water.</li>
        <li><b>add_water_only()</b> → Add only water.</li>
        <li><b>stir_and_serve()</b> → Serve normally.</li>
        <li><b>chill_and_serve()</b> → Serve cold.</li>
    </ul>

    <h3>🧠 Router Nodes</h3>

    <p>
        Router nodes act as decision points within the graph.
        They don't modify the state but determine the next path.
    </p>

    <ul>
        <li><b>router_1</b> → Determines sugar path.</li>
        <li><b>router_2</b> → Determines serving method.</li>
    </ul>

    <h3>✅ Decision Logic</h3>

    <h4>Decision 1: Sugar Check</h4>

    <pre style="background:#f4f4f4;padding:10px;">
If sugar > 0
    → add_sugar_and_water
Else
    → add_water_only
    </pre>

    <h4>Decision 2: Serving Preference</h4>

    <pre style="background:#f4f4f4;padding:10px;">
If prefer_cold = True
    → chill_and_serve
Else
    → stir_and_serve
    </pre>

    <h3>📈 Workflow Diagram</h3>

    <div style="background:#f8f9fa;padding:15px;border-radius:6px;
                font-family:Consolas,monospace;">

squeeze_lemons<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
router_1<br>
&nbsp;&nbsp;/&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\\<br>
Sugar&gt;0&nbsp;&nbsp;&nbsp;&nbsp;Sugar=0<br>
&nbsp;&nbsp;&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
add_sugar_and_water&nbsp;&nbsp;&nbsp;add_water_only<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;router_2<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;/&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\\<br>
Cold&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Normal<br>
&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
chill_and_serve&nbsp;&nbsp;&nbsp;stir_and_serve<br>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br>
END

    </div>

    <h3>🚀 Graph Execution Flow</h3>

    <ol>
        <li>Squeeze lemons.</li>
        <li>Check whether sugar is available.</li>
        <li>Prepare the appropriate mixture.</li>
        <li>Check serving preference.</li>
        <li>Serve chilled or normally.</li>
        <li>Return final state.</li>
    </ol>

    <h3>🧪 Scenario 1</h3>

    <div style="background:#e8f4fd;padding:12px;
                border-left:4px solid #0078d4;border-radius:4px;">

        <b>Input</b><br>
        Lemons = 4<br>
        Sugar = 2<br>
        Water = 1 Glass<br>
        Prefer Cold = False
        <br><br>

        <b>Path Selected</b><br>
        squeeze_lemons → router_1 → add_sugar_and_water
        → router_2 → stir_and_serve
        <br><br>

        <b>Output</b><br>
        Juice from 4 lemons + 2 spoons sugar + 1 glass water
        → Stirred and ready to serve!
    </div>

    <br>

    <h3>🧪 Scenario 2</h3>

    <div style="background:#fff4ce;padding:12px;
                border-left:4px solid #ffb900;border-radius:4px;">

        <b>Input</b><br>
        Lemons = 3<br>
        Sugar = 0<br>
        Water = 2 Glasses<br>
        Prefer Cold = True
        <br><br>

        <b>Path Selected</b><br>
        squeeze_lemons → router_1 → add_water_only
        → router_2 → chill_and_serve
        <br><br>

        <b>Output</b><br>
        Juice from 3 lemons + 2 glasses water
        → Chilled and served!
    </div>

    <br>

    <h3>📊 DataFrame Output</h3>

    <p>
        After executing all scenarios, results are stored in a list and
        converted into a Pandas DataFrame for easy visualization and analysis.
    </p>

    <pre style="background:#f4f4f4;padding:10px;">
df = pd.DataFrame(results)
df
    </pre>

    <h3>🎯 LangGraph Concepts Demonstrated</h3>

    <div style="background:#f3f2f1;padding:12px;border-radius:6px;">

        <b>State</b> → Shared memory across nodes<br><br>

        <b>Node</b> → Individual processing step<br><br>

        <b>Edge</b> → Connection between nodes<br><br>

        <b>Conditional Edge</b> → Dynamic branching logic<br><br>

        <b>Router</b> → Decision-making node<br><br>

        <b>Multiple Routing Levels</b> → More than one decision point<br><br>

        <b>Graph</b> → Complete workflow orchestration<br><br>

        <b>Invoke</b> → Executes the workflow from start to end

    </div>

    <br>

    <div style="background:#dff6dd;padding:12px;
                border-left:4px solid #107c10;border-radius:4px;">
        <strong>
            Key Learning: This example demonstrates a true LangGraph workflow
            where multiple decision points dynamically alter the execution path.
            This pattern is commonly used in AMS Incident Management, Ticket Routing,
            Approval Workflows, RAG Systems, Customer Support Bots, and Multi-Agent AI solutions.
        </strong>
    </div>

</div>
"""
display(HTML(langgraph_double_condition_html))
# Out:
# <div style="font-family:Segoe UI,Arial,sans-serif;line-height:1.6;">
#
#     <h2 style="color:#0078d4;">
#         LangGraph Multi-Level Conditional Routing Example
#     </h2>
#
#     <p>
#         This example demonstrates how <b>LangGraph</b> can perform
#         <b>multiple decision-making steps</b> within the same workflow.
#         The graph first decides whether sugar should be added and then
#         decides how the lemonade should be served.
#     </p>
#
#     <h3>🎯 Business Scenario</h3>
#
#     <p>
#         We are preparing lemonade dynamically based on user preferences:
#     </p>
#
#     <ul>
#         <li>If sugar is available, add sugar and water.</li>
#         <li>If sugar is unavailable, add only water.</li>
#         <li>If the customer prefers a cold drink, chill and serve.</li>
#         <li>Otherwise, stir and serve normally.</li>
#     </ul>
#
#     <h3>📦 State Object</h3>
#
#     <p>
# ...

# %% [markdown]
# ![My Animation](doublewithlemonJuice.gif)

# %%
# Re-running the code after execution environment reset
from langgraph.graph import StateGraph
from typing import TypedDict, Dict, Any
from IPython.display import Image, display

# 1. Define state structure
class LemonState(TypedDict):
    lemons: int
    sugar: int
    water: str
    juice: str
    mix: str
    final: str
    prefer_cold: bool

# 2. Define processing nodes
def squeeze_lemons(state: Dict[str, Any]) -> Dict[str, Any]:
    state["juice"] = f"Juice from {state.get('lemons', 0)} lemons"
    return state

def add_sugar_and_water(state: Dict[str, Any]) -> Dict[str, Any]:
    state["mix"] = f"{state['juice']} + {state['sugar']} spoons sugar + {state['water']} water"
    return state

def add_water_only(state: Dict[str, Any]) -> Dict[str, Any]:
    state["mix"] = f"{state['juice']} + {state['water']} water"
    return state

def stir_and_serve(state: Dict[str, Any]) -> Dict[str, Any]:
    state["final"] = f"{state['mix']} → Stirred and ready to serve!"
    return state

def chill_and_serve(state: Dict[str, Any]) -> Dict[str, Any]:
    state["final"] = f"{state['mix']} → Chilled and served!"
    return state

# 3. Router nodes (just pass state through)
def router_1(state: Dict[str, Any]) -> Dict[str, Any]:
    return state

def router_2(state: Dict[str, Any]) -> Dict[str, Any]:
    return state

# 4. Decision functions
def check_sugar(state: Dict[str, Any]) -> str:
    return "add_sugar_and_water" if state.get("sugar", 0) > 0 else "add_water_only"

def route_serving(state: Dict[str, Any]) -> str:
    return "chill_and_serve" if state.get("prefer_cold", False) else "stir_and_serve"

# 5. Build graph
builder = StateGraph(LemonState)
builder.add_node("squeeze_lemons", squeeze_lemons)
builder.add_node("router_1", router_1)
builder.add_node("add_sugar_and_water", add_sugar_and_water)
builder.add_node("add_water_only", add_water_only)
builder.add_node("router_2", router_2)
builder.add_node("stir_and_serve", stir_and_serve)
builder.add_node("chill_and_serve", chill_and_serve)

builder.set_entry_point("squeeze_lemons")
builder.add_edge("squeeze_lemons", "router_1")

# First branching: sugar or not
builder.add_conditional_edges("router_1", check_sugar, {
    "add_sugar_and_water": "add_sugar_and_water",
    "add_water_only": "add_water_only"
})

# After either mix path, go to second router
builder.add_edge("add_sugar_and_water", "router_2")
builder.add_edge("add_water_only", "router_2")

# Second branching: serve cold or not
builder.add_conditional_edges("router_2", route_serving, {
    "stir_and_serve": "stir_and_serve",
    "chill_and_serve": "chill_and_serve"
})

# Define finish nodes
builder.set_finish_point("stir_and_serve")
builder.set_finish_point("chill_and_serve")

# Compile
graph = builder.compile()

# Visualize
from IPython.display import Image, Markdown, display

try:
    png_data = graph.get_graph().draw_mermaid_png()
    display(Image(png_data))

except Exception as e:
    print(f"Graph Visualization Failed: {e}")

    mermaid_code = graph.get_graph().draw_mermaid()

    display(
        Markdown(
            f"```mermaid\n{mermaid_code}\n```"
        )
    )

# Test examples
scenarios = [
    {"lemons": 4, "sugar": 2, "water": "1 glass", "prefer_cold": False},
    {"lemons": 3, "sugar": 0, "water": "2 glasses", "prefer_cold": True},
]

results = []
for scenario in scenarios:
    state = {
        **scenario,
        "juice": "",
        "mix": "",
        "final": ""
    }
    result = graph.invoke(state)
    results.append(result)

import pandas as pd

df = pd.DataFrame(results)
df
# Out:
# Graph Visualization Failed: Failed to reach https://mermaid.ink API while trying to render your graph after 1 retries. To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	squeeze_lemons(squeeze_lemons)
# 	router_1(router_1)
# 	add_sugar_and_water(add_sugar_and_water)
# 	add_water_only(add_water_only)
# 	router_2(router_2)
# 	stir_and_serve(stir_and_serve)
# 	chill_and_serve(chill_and_serve)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> squeeze_lemons;
# 	add_sugar_and_water --> router_2;
# 	add_water_only --> router_2;
# 	router_1 -.-> add_sugar_and_water;
# ...
