# %%
from IPython.display import display, HTML

inner_html = """
<div style="font-family:Segoe UI,Arial,sans-serif;line-height:1.6;">

    <h2 style="color:#0078d4;">
        LangGraph Loop with Conditional Skip Example
    </h2>

    <p>
        This example demonstrates two powerful LangGraph capabilities:
    </p>

    <ul>
        <li><b>Looping</b> - Repeat execution until a condition is satisfied.</li>
        <li><b>Conditional Skipping</b> - Dynamically skip specific nodes based on the current state.</li>
    </ul>

    <h3>🎯 Business Scenario</h3>

    <p>
        A lemonade preparation process needs to continue adding sugar until the
        drink becomes sweet enough. During the first execution, water is added.
        During subsequent iterations, the workflow skips the water-adding step
        and directly proceeds to sugar adjustment.
    </p>

    <h3>📦 State Definition</h3>

    <p>
        <b>LemonSkipState</b> acts as the shared workflow memory.
    </p>

    <ul>
        <li><b>lemons</b> → Number of lemons used.</li>
        <li><b>sugar</b> → Current sugar quantity.</li>
        <li><b>water</b> → Water quantity.</li>
        <li><b>juice</b> → Lemon juice generated.</li>
        <li><b>mix</b> → Lemonade mixture.</li>
        <li><b>sweet</b> → Whether the lemonade is sweet enough.</li>
        <li><b>attempts</b> → Number of sugar adjustment attempts.</li>
        <li><b>skip_water</b> → Controls whether water should be skipped.</li>
        <li><b>final</b> → Final output.</li>
    </ul>

    <h3>🔧 Processing Nodes</h3>

    <ul>
        <li>
            <b>squeeze_lemons()</b><br/>
            Extracts juice from lemons.
        </li>

        <li>
            <b>add_water()</b><br/>
            Adds water to the lemonade.
        </li>

        <li>
            <b>add_sugar()</b><br/>
            Adds one spoon of sugar and increments the attempt counter.
        </li>

        <li>
            <b>taste_and_check()</b><br/>
            Checks whether the lemonade has become sweet enough.
        </li>

        <li>
            <b>serve()</b><br/>
            Serves the lemonade once the required sweetness level is achieved.
        </li>
    </ul>

    <h3>🧠 Decision Point #1 - Skip Water Logic</h3>

    <pre style="background:#f4f4f4;padding:10px;">
If skip_water = False
    → add_water

If skip_water = True
    → add_sugar
    </pre>

    <p>
        Initially, water is added. After the first sugar adjustment,
        <b>skip_water</b> becomes True and future iterations bypass the
        water node completely.
    </p>

    <h3>🧠 Decision Point #2 - Sweetness Check</h3>

    <pre style="background:#f4f4f4;padding:10px;">
If sweet = True
    → serve

Else
    → squeeze_lemons
    → continue loop
    </pre>

    <h3>🔄 Workflow Diagram</h3>

    <div style="background:#f8f9fa;padding:15px;border-radius:6px;
                font-family:Consolas,monospace;">

squeeze_lemons<br/>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
Conditional Route<br/>
&nbsp;&nbsp;&nbsp;&nbsp;/&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\\<br/>
add_water&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;skip_water=True<br/>
&nbsp;&nbsp;&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
add_sugar&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;←<br/>
&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
taste_and_check<br/>
&nbsp;&nbsp;&nbsp;&nbsp;/&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\\<br/>
sweet=True&nbsp;&nbsp;&nbsp;Not Sweet<br/>
&nbsp;&nbsp;&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓<br/>
serve&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;squeeze_lemons<br/>
&nbsp;&nbsp;&nbsp;&nbsp;↓&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↺ Loop<br/>
END

    </div>

    <h3>🚀 Sample Execution Flow</h3>

    <div style="background:#e8f4fd;padding:12px;
                border-left:4px solid #0078d4;border-radius:4px;">

        <b>Initial Values</b><br/>
        Lemons = 4<br/>
        Sugar = 0<br/>
        Water = 1 Glass<br/>
        Skip Water = False
        <br/><br/>

        <b>Iteration 1</b><br/>
        squeeze_lemons → add_water → add_sugar → taste_and_check
        <br/>
        Sugar = 1 → Not Sweet
        <br/><br/>

        <b>Iteration 2</b><br/>
        squeeze_lemons → add_sugar → taste_and_check
        <br/>
        Water Step Skipped ✅
        <br/>
        Sugar = 2 → Sweet
        <br/><br/>

        <b>Final Step</b><br/>
        serve
    </div>

    <br/>

    <h3>📋 Expected Final State</h3>

    <div style="background:#fff4ce;padding:12px;
                border-left:4px solid #ffb900;border-radius:4px;">

        <b>sugar:</b> 2<br/>
        <b>attempts:</b> 2<br/>
        <b>sweet:</b> True<br/>
        <b>skip_water:</b> True<br/>
        <b>final:</b> Juice from 4 lemons + 1 glass water + 2 spoons sugar → Served!

    </div>

    <br/>

    <h3>🎯 LangGraph Concepts Demonstrated</h3>

    <div style="background:#f3f2f1;padding:12px;border-radius:6px;">

        <b>State Management</b> → Shared workflow memory<br/><br/>

        <b>Nodes</b> → Individual processing steps<br/><br/>

        <b>Conditional Routing</b> → Dynamic path selection<br/><br/>

        <b>Looping</b> → Repeat workflow until condition satisfied<br/><br/>

        <b>Node Skipping</b> → Bypass unnecessary processing<br/><br/>

        <b>State-Based Decisions</b> → Route based on runtime values<br/><br/>

        <b>Finish Node</b> → Controlled workflow termination

    </div>

    <br/>

    <div style="background:#dff6dd;padding:12px;
                border-left:4px solid #107c10;border-radius:4px;">

        <strong>
            Key Learning: This example combines looping and conditional skipping.
            The workflow intelligently avoids re-executing the water step during
            subsequent iterations, making the process more efficient. Similar
            patterns are frequently used in AMS Incident Resolution, Retry
            Mechanisms, Root Cause Analysis, Approval Workflows, Agentic AI,
            and Self-Correcting Enterprise Applications.
        </strong>

    </div>

</div>
"""
display(HTML(inner_html))
# Out:
# <div style="font-family:Segoe UI,Arial,sans-serif;line-height:1.6;">
#
#     <h2 style="color:#0078d4;">
#         LangGraph Loop with Conditional Skip Example
#     </h2>
#
#     <p>
#         This example demonstrates two powerful LangGraph capabilities:
#     </p>
#
#     <ul>
#         <li><b>Looping</b> - Repeat execution until a condition is satisfied.</li>
#         <li><b>Conditional Skipping</b> - Dynamically skip specific nodes based on the current state.</li>
#     </ul>
#
#     <h3>🎯 Business Scenario</h3>
#
#     <p>
#         A lemonade preparation process needs to continue adding sugar until the
#         drink becomes sweet enough. During the first execution, water is added.
#         During subsequent iterations, the workflow skips the water-adding step
#         and directly proceeds to sugar adjustment.
#     </p>
#
#     <h3>📦 State Definition</h3>
#
#     <p>
#         <b>LemonSkipState</b> acts as the shared workflow memory.
#     </p>
#
#     <ul>
# ...

# %%
from langgraph.graph import StateGraph
from typing import TypedDict, Dict, Any

# Define the updated state with skip flag and attempt count
class LemonSkipState(TypedDict):
    lemons: int
    sugar: int
    water: str
    juice: str
    mix: str
    final: str
    sweet: bool
    attempts: int
    skip_water: bool  # controls skipping

# Nodes
def squeeze_lemons(state: Dict[str, Any]) -> Dict[str, Any]:
    state["juice"] = f"Juice from {state['lemons']} lemons"
    return state

def add_water(state: Dict[str, Any]) -> Dict[str, Any]:
    state["mix"] = f"{state['juice']} + {state['water']} water"
    return state

def add_sugar(state: Dict[str, Any]) -> Dict[str, Any]:
    state["sugar"] += 1
    state["attempts"] += 1
    state["mix"] = f"{state['juice']} + {state['water']} water + {state['sugar']} spoons sugar"
    return state

def taste_and_check(state: Dict[str, Any]) -> Dict[str, Any]:
    # Consider sweet if sugar >= 2
    state["sweet"] = state["sugar"] >= 2
    # After first loop, skip water
    if state["attempts"] >= 1:
        state["skip_water"] = True
    return state

def serve(state: Dict[str, Any]) -> Dict[str, Any]:
    state["final"] = f"{state['mix']} → Served!"
    return state

# Decision function to skip water
def route_after_squeeze(state: Dict[str, Any]) -> str:
    return "add_sugar" if state.get("skip_water", False) else "add_water"

# Looping condition
def check_sweetness(state: Dict[str, Any]) -> str:
    return "serve" if state["sweet"] else "squeeze_lemons"

# Build graph
builder = StateGraph(LemonSkipState)
builder.add_node("squeeze_lemons", squeeze_lemons)
builder.add_node("add_water", add_water)
builder.add_node("add_sugar", add_sugar)
builder.add_node("taste_and_check", taste_and_check)
builder.add_node("serve", serve)

builder.set_entry_point("squeeze_lemons")

# After squeezing, route based on skip_water
builder.add_conditional_edges("squeeze_lemons", route_after_squeeze, {
    "add_water": "add_water",
    "add_sugar": "add_sugar"
})

builder.add_edge("add_water", "add_sugar")
builder.add_edge("add_sugar", "taste_and_check")

builder.add_conditional_edges("taste_and_check", check_sweetness, {
    "serve": "serve",
    "squeeze_lemons": "squeeze_lemons"
})

builder.set_finish_point("serve")

# Compile and run
#graph = builder.compile()

from IPython.display import Image, Markdown, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))

except Exception as e:
    print(f"Graph Visualization Failed: {e}")

    mermaid_code = graph.get_graph().draw_mermaid()

    display(
        Markdown(
            f"```mermaid\n{mermaid_code}\n```"
        )
    )


initial_state = {
    "lemons": 4,
    "sugar": 0,
    "water": "1 glass",
    "juice": "",
    "mix": "",
    "final": "",
    "sweet": False,
    "attempts": 0,
    "skip_water": False
}

result = graph.invoke(initial_state)
# Out:
# Graph Visualization Failed: name 'graph' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 83
#      82 try:
# ---> 83     display(Image(graph.get_graph().draw_mermaid_png()))
#      85 except Exception as e:
#
# NameError: name 'graph' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 88
#      85 except Exception as e:
#      86     print(f"Graph Visualization Failed: {e}")
# ---> 88     mermaid_code = graph.get_graph().draw_mermaid()
#      90     display(
#      91         Markdown(
#      92             f"```mermaid\n{mermaid_code}\n```"
#      93         )
#      94     )
#      97 initial_state = {
#      98     "lemons": 4,
#      99     "sugar": 0,
#    (...)
#     106     "skip_water": False
# ...

# %%
import pandas as pd
result_df = pd.DataFrame([result])
result_df
